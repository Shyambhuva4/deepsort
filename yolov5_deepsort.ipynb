# %% [markdown]
# # Object Tracking Using Yolov5 + DeepSort
#
# The detections generated by YOLOv5, a family of object detection architectures and models pretrained on the COCO dataset, are passed to StrongSORT which combines motion and appearance information based on OSNet in order to tracks the objects. It can track any object that your Yolov5 model was trained to detect

# %%
# !cd
# Out:
# d:\code\yolov5\Yolov5_DeepSort_Pytorch

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch.git
# Out:
# Submodule path 'strong_sort/deep/reid': checked out '4a0793780bd13f53ec2ca753a94dcef62dc9e955'
# Submodule path 'yolov5': checked out '91a81d48fa4e34dbdbaf0e45a1f841c11216aab5'
# Cloning into 'Yolov5_DeepSort_Pytorch'...
# Submodule 'strong_sort/deep/reid' (https://github.com/KaiyangZhou/deep-person-reid) registered for path 'strong_sort/deep/reid'
# Submodule 'yolov5' (https://github.com/ultralytics/yolov5.git) registered for path 'yolov5'
# Cloning into 'D:/code/yolov5/Yolov5_DeepSort_Pytorch/strong_sort/deep/reid'...
# Cloning into 'D:/code/yolov5/Yolov5_DeepSort_Pytorch/yolov5'...

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.20.3)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (4.6.0.66)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (8.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (2.26.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (1.7.1)
# Requirement already satisfied: torch>=1.7.0 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (1.12.1)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 12)) (0.13.1)
# Collecting tqdm>=4.64.0
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: protobuf<=3.20.1 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 14)) (3.19.4)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 18)) (1.3.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 19)) (0.11.2)
# Requirement already satisfied: easydict in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 23)) (1.9)
# Requirement already satisfied: Cython in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 27)) (0.29.24)
# Requirement already satisfied: h5py in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 28)) (3.2.1)
# Requirement already satisfied: six in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 29)) (1.16.0)
# Collecting tb-nightly
#   Using cached tb_nightly-2.11.0a20220910-py3-none-any.whl (5.9 MB)
# Requirement already satisfied: future in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 31)) (0.18.2)
# Collecting yacs
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting gdown
#   Using cached gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: flake8 in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 34)) (3.9.2)
# Requirement already satisfied: yapf in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 35)) (0.31.0)
# Collecting isort==4.3.21
#   Using cached isort-4.3.21-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: imageio in c:\users\shyam\anaconda3\lib\site-packages (from -r requirements.txt (line 37)) (2.9.0)
# Collecting GitPython
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\shyam\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shyam\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shyam\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shyam\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shyam\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shyam\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shyam\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\shyam\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.4)
# Requirement already satisfied: typing-extensions in c:\users\shyam\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (3.10.0.2)
# Requirement already satisfied: colorama in c:\users\shyam\anaconda3\lib\site-packages (from tqdm>=4.64.0->-r requirements.txt (line 13)) (0.4.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\shyam\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 18)) (2021.3)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (1.47.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (58.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (0.37.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (1.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (2.11.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\shyam\anaconda3\lib\site-packages (from tb-nightly->-r requirements.txt (line 30)) (0.6.1)
# Requirement already satisfied: filelock in c:\users\shyam\anaconda3\lib\site-packages (from gdown->-r requirements.txt (line 33)) (3.3.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\shyam\anaconda3\lib\site-packages (from gdown->-r requirements.txt (line 33)) (4.10.0)
# Requirement already satisfied: pyflakes<2.4.0,>=2.3.0 in c:\users\shyam\anaconda3\lib\site-packages (from flake8->-r requirements.txt (line 34)) (2.3.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in c:\users\shyam\anaconda3\lib\site-packages (from flake8->-r requirements.txt (line 34)) (0.6.1)
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in c:\users\shyam\anaconda3\lib\site-packages (from flake8->-r requirements.txt (line 34)) (2.7.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\shyam\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 30)) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shyam\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 30)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\shyam\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 30)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\shyam\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly->-r requirements.txt (line 30)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\shyam\anaconda3\lib\site-packages (from markdown>=2.6.8->tb-nightly->-r requirements.txt (line 30)) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\shyam\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly->-r requirements.txt (line 30)) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\shyam\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 30)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\shyam\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly->-r requirements.txt (line 30)) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shyam\anaconda3\lib\site-packages (from beautifulsoup4->gdown->-r requirements.txt (line 33)) (2.2.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\shyam\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517): started
#   Building wheel for gdown (PEP 517): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=d569b94e0683fdd07c9fc8b209160d0a9d1f0ee9c066afb0d26bbfa710988123
#   Stored in directory: c:\users\shyam\appdata\local\pip\cache\wheels\b8\79\f0\b523d25d96b0bbb12bb024b97940d08c4fcd498a00070c8d82
# Successfully built gdown
# Installing collected packages: smmap, tqdm, gitdb, yacs, tb-nightly, isort, GitPython, gdown
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: isort
#     Found existing installation: isort 5.9.3
#     Uninstalling isort-5.9.3:
#       Successfully uninstalled isort-5.9.3
# Successfully installed GitPython-3.1.27 gdown-4.5.1 gitdb-4.0.9 isort-4.3.21 smmap-5.0.0 tb-nightly-2.11.0a20220910 tqdm-4.64.1 yacs-0.1.8

# %%
# !pip show python-utils
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# !python track.py --source Oranges.mp4 --yolo-weights best.pt --show-vid #own_weight
# !python track.py --source Oranges.mp4 --show-vid #pretrained weights
# Out:
# True
# True
# Successfully loaded pretrained weights from "D:\code\yolov5\Yolov5_DeepSort_Pytorch\weights\osnet_x0_25_msmt17.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# d:\code\yolov5\Yolov5_DeepSort_Pytorch\strong_sort/deep/reid\torchreid\metrics\rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# track: yolo_weights=[WindowsPath('best.pt')], strong_sort_weights=D:\code\yolov5\Yolov5_DeepSort_Pytorch\weights\osnet_x0_25_msmt17.pt, config_strongsort=strong_sort/configs/strong_sort.yaml, source=Oranges.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=True, save_txt=False, save_conf=False, save_crop=False, save_vid=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\track, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, eval=False
# YOLOv5  2022-9-10 Python-3.9.7 torch-1.12.1+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (12/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.732s), StrongSORT:(0.087s)
# No detections
# video 1/1 (14/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.926s), StrongSORT:(0.137s)
# video 1/1 (15/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.899s), StrongSORT:(0.086s)
# video 1/1 (16/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.964s), StrongSORT:(0.087s)
# video 1/1 (17/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.923s), StrongSORT:(0.071s)
# video 1/1 (18/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.895s), StrongSORT:(0.088s)
# video 1/1 (19/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.916s), StrongSORT:(0.104s)
# video 1/1 (20/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.869s), StrongSORT:(0.085s)
# video 1/1 (21/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.823s), StrongSORT:(0.078s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (28/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.872s), StrongSORT:(0.083s)
# video 1/1 (29/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.858s), StrongSORT:(0.081s)
# video 1/1 (30/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.844s), StrongSORT:(0.082s)
# video 1/1 (31/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.832s), StrongSORT:(0.089s)
# video 1/1 (32/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.866s), StrongSORT:(0.085s)
# video 1/1 (33/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.088s)
# video 1/1 (34/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.853s), StrongSORT:(0.092s)
# video 1/1 (35/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.863s), StrongSORT:(0.106s)
# video 1/1 (36/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.817s), StrongSORT:(0.096s)
# video 1/1 (37/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.917s), StrongSORT:(0.082s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (46/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.855s), StrongSORT:(0.084s)
# video 1/1 (47/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.111s)
# video 1/1 (48/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.848s), StrongSORT:(0.085s)
# video 1/1 (49/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.833s), StrongSORT:(0.093s)
# video 1/1 (50/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.830s), StrongSORT:(0.096s)
# video 1/1 (51/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.846s), StrongSORT:(0.088s)
# video 1/1 (52/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.845s), StrongSORT:(0.087s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (63/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.852s), StrongSORT:(0.093s)
# video 1/1 (64/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.845s), StrongSORT:(0.092s)
# video 1/1 (65/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.920s), StrongSORT:(0.068s)
# video 1/1 (66/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.818s), StrongSORT:(0.084s)
# video 1/1 (67/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.837s), StrongSORT:(0.082s)
# video 1/1 (68/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.828s), StrongSORT:(0.081s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (96/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.882s), StrongSORT:(0.090s)
# video 1/1 (97/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.854s), StrongSORT:(0.090s)
# video 1/1 (98/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.872s), StrongSORT:(0.101s)
# video 1/1 (99/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.869s), StrongSORT:(0.079s)
# video 1/1 (100/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.826s), StrongSORT:(0.092s)
# video 1/1 (101/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.863s), StrongSORT:(0.088s)
# video 1/1 (102/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.851s), StrongSORT:(0.099s)
# video 1/1 (103/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.863s), StrongSORT:(0.094s)
# video 1/1 (104/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.832s), StrongSORT:(0.088s)
# video 1/1 (105/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.812s), StrongSORT:(0.080s)
# video 1/1 (106/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.853s), StrongSORT:(0.079s)
# video 1/1 (107/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.840s), StrongSORT:(0.087s)
# video 1/1 (108/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.797s), StrongSORT:(0.088s)
# video 1/1 (109/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.864s), StrongSORT:(0.088s)
# video 1/1 (110/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.831s), StrongSORT:(0.124s)
# video 1/1 (111/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.861s), StrongSORT:(0.083s)
# video 1/1 (112/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.835s), StrongSORT:(0.092s)
# video 1/1 (113/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.844s), StrongSORT:(0.082s)
# video 1/1 (114/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.826s), StrongSORT:(0.081s)
# video 1/1 (115/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.827s), StrongSORT:(0.091s)
# video 1/1 (116/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.830s), StrongSORT:(0.089s)
# video 1/1 (117/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.851s), StrongSORT:(0.100s)
# No detections
# video 1/1 (119/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.855s), StrongSORT:(0.100s)
# video 1/1 (120/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.098s)
# video 1/1 (121/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.876s), StrongSORT:(0.087s)
# video 1/1 (122/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.836s), StrongSORT:(0.101s)
# video 1/1 (123/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.853s), StrongSORT:(0.094s)
# video 1/1 (124/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.814s), StrongSORT:(0.097s)
# video 1/1 (125/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.861s), StrongSORT:(0.084s)
# video 1/1 (126/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.857s), StrongSORT:(0.084s)
# video 1/1 (127/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.841s), StrongSORT:(0.090s)
# video 1/1 (128/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.866s), StrongSORT:(0.113s)
# video 1/1 (129/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.885s), StrongSORT:(0.089s)
# video 1/1 (130/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.845s), StrongSORT:(0.087s)
# video 1/1 (131/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.820s), StrongSORT:(0.088s)
# video 1/1 (132/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.861s), StrongSORT:(0.097s)
# video 1/1 (133/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.874s), StrongSORT:(0.083s)
# video 1/1 (134/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.861s), StrongSORT:(0.088s)
# video 1/1 (135/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.824s), StrongSORT:(0.096s)
# video 1/1 (136/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.821s), StrongSORT:(0.095s)
# video 1/1 (137/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.859s), StrongSORT:(0.102s)
# video 1/1 (138/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.862s), StrongSORT:(0.088s)
# video 1/1 (139/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.855s), StrongSORT:(0.094s)
# video 1/1 (140/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.814s), StrongSORT:(0.092s)
# video 1/1 (141/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.867s), StrongSORT:(0.074s)
# video 1/1 (142/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.827s), StrongSORT:(0.093s)
# video 1/1 (143/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.852s), StrongSORT:(0.082s)
# video 1/1 (144/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.856s), StrongSORT:(0.094s)
# video 1/1 (145/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.882s), StrongSORT:(0.080s)
# video 1/1 (146/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.857s), StrongSORT:(0.085s)
# video 1/1 (147/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.839s), StrongSORT:(0.082s)
# video 1/1 (148/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.844s), StrongSORT:(0.090s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (158/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.887s), StrongSORT:(0.084s)
# video 1/1 (159/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.862s), StrongSORT:(0.096s)
# video 1/1 (160/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.864s), StrongSORT:(0.082s)
# video 1/1 (161/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.867s), StrongSORT:(0.089s)
# video 1/1 (162/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.866s), StrongSORT:(0.096s)
# video 1/1 (163/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.856s), StrongSORT:(0.083s)
# video 1/1 (164/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.850s), StrongSORT:(0.092s)
# video 1/1 (165/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.844s), StrongSORT:(0.092s)
# video 1/1 (166/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.845s), StrongSORT:(0.097s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (181/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.823s), StrongSORT:(0.093s)
# video 1/1 (182/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.855s), StrongSORT:(0.092s)
# video 1/1 (183/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.827s), StrongSORT:(0.093s)
# video 1/1 (184/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.832s), StrongSORT:(0.099s)
# video 1/1 (185/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.845s), StrongSORT:(0.078s)
# No detections
# video 1/1 (187/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.872s), StrongSORT:(0.088s)
# No detections
# video 1/1 (189/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.823s), StrongSORT:(0.085s)
# video 1/1 (190/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.839s), StrongSORT:(0.089s)
# video 1/1 (191/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.849s), StrongSORT:(0.114s)
# video 1/1 (192/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.913s), StrongSORT:(0.087s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (221/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.835s), StrongSORT:(0.080s)
# video 1/1 (222/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.879s), StrongSORT:(0.095s)
# video 1/1 (223/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.866s), StrongSORT:(0.084s)
# video 1/1 (224/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.910s), StrongSORT:(0.083s)
# video 1/1 (225/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.824s), StrongSORT:(0.086s)
# video 1/1 (226/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.837s), StrongSORT:(0.085s)
# video 1/1 (227/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.868s), StrongSORT:(0.087s)
# video 1/1 (228/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.832s), StrongSORT:(0.085s)
# video 1/1 (229/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.086s)
# video 1/1 (230/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.839s), StrongSORT:(0.084s)
# video 1/1 (231/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.837s), StrongSORT:(0.080s)
# video 1/1 (232/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.854s), StrongSORT:(0.082s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (242/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.848s), StrongSORT:(0.087s)
# video 1/1 (243/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.850s), StrongSORT:(0.080s)
# video 1/1 (244/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.861s), StrongSORT:(0.095s)
# video 1/1 (245/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.859s), StrongSORT:(0.088s)
# video 1/1 (246/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.091s)
# video 1/1 (247/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.823s), StrongSORT:(0.102s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (261/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.814s), StrongSORT:(0.094s)
# video 1/1 (262/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.837s), StrongSORT:(0.086s)
# video 1/1 (263/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.866s), StrongSORT:(0.099s)
# video 1/1 (264/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.827s), StrongSORT:(0.082s)
# video 1/1 (265/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.833s), StrongSORT:(0.101s)
# video 1/1 (266/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.861s), StrongSORT:(0.095s)
# video 1/1 (267/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.856s), StrongSORT:(0.087s)
# video 1/1 (268/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.838s), StrongSORT:(0.085s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (287/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.855s), StrongSORT:(0.083s)
# No detections
# No detections
# No detections
# No detections
# video 1/1 (292/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.825s), StrongSORT:(0.079s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (315/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.918s), StrongSORT:(0.113s)
# No detections
# No detections
# No detections
# video 1/1 (319/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.825s), StrongSORT:(0.080s)
# No detections
# video 1/1 (321/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.844s), StrongSORT:(0.082s)
# No detections
# video 1/1 (323/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.874s), StrongSORT:(0.103s)
# video 1/1 (324/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.844s), StrongSORT:(0.084s)
# video 1/1 (325/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.859s), StrongSORT:(0.079s)
# video 1/1 (326/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.858s), StrongSORT:(0.082s)
# video 1/1 (327/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.860s), StrongSORT:(0.093s)
# video 1/1 (328/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.872s), StrongSORT:(0.095s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (346/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.903s), StrongSORT:(0.111s)
# video 1/1 (347/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.898s), StrongSORT:(0.103s)
# video 1/1 (348/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.894s), StrongSORT:(0.085s)
# video 1/1 (349/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.861s), StrongSORT:(0.093s)
# video 1/1 (350/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.845s), StrongSORT:(0.135s)
# video 1/1 (351/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.855s), StrongSORT:(0.159s)
# video 1/1 (352/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.874s), StrongSORT:(0.155s)
# video 1/1 (353/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.865s), StrongSORT:(0.137s)
# video 1/1 (354/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.857s), StrongSORT:(0.080s)
# video 1/1 (355/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 3 oranges, Done. YOLO:(0.819s), StrongSORT:(0.203s)
# video 1/1 (356/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.896s), StrongSORT:(0.139s)
# video 1/1 (357/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.845s), StrongSORT:(0.095s)
# video 1/1 (358/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.871s), StrongSORT:(0.093s)
# video 1/1 (359/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.863s), StrongSORT:(0.100s)
# video 1/1 (360/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.864s), StrongSORT:(0.082s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (377/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.857s), StrongSORT:(0.085s)
# video 1/1 (378/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.897s), StrongSORT:(0.087s)
# No detections
# video 1/1 (380/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.839s), StrongSORT:(0.095s)
# video 1/1 (381/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.860s), StrongSORT:(0.088s)
# video 1/1 (382/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.853s), StrongSORT:(0.152s)
# video 1/1 (383/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.915s), StrongSORT:(0.140s)
# video 1/1 (384/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.848s), StrongSORT:(0.146s)
# video 1/1 (385/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.836s), StrongSORT:(0.154s)
# video 1/1 (386/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.847s), StrongSORT:(0.141s)
# video 1/1 (387/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.845s), StrongSORT:(0.100s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (418/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.863s), StrongSORT:(0.093s)
# video 1/1 (419/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.825s), StrongSORT:(0.092s)
# No detections
# video 1/1 (421/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.844s), StrongSORT:(0.091s)
# video 1/1 (422/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.839s), StrongSORT:(0.084s)
# video 1/1 (423/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.835s), StrongSORT:(0.082s)
# video 1/1 (424/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 3 oranges, Done. YOLO:(0.866s), StrongSORT:(0.178s)
# video 1/1 (425/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 3 oranges, Done. YOLO:(0.851s), StrongSORT:(0.187s)
# video 1/1 (426/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 3 oranges, Done. YOLO:(0.834s), StrongSORT:(0.207s)
# video 1/1 (427/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.875s), StrongSORT:(0.153s)
# video 1/1 (428/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.922s), StrongSORT:(0.141s)
# video 1/1 (429/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.827s), StrongSORT:(0.137s)
# video 1/1 (430/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.848s), StrongSORT:(0.141s)
# video 1/1 (431/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.853s), StrongSORT:(0.158s)
# video 1/1 (432/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.829s), StrongSORT:(0.134s)
# video 1/1 (433/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.874s), StrongSORT:(0.092s)
# video 1/1 (434/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.855s), StrongSORT:(0.096s)
# video 1/1 (435/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.877s), StrongSORT:(0.096s)
# video 1/1 (436/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.833s), StrongSORT:(0.092s)
# video 1/1 (437/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.847s), StrongSORT:(0.084s)
# video 1/1 (438/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.858s), StrongSORT:(0.088s)
# video 1/1 (439/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.842s), StrongSORT:(0.096s)
# video 1/1 (440/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.877s), StrongSORT:(0.141s)
# video 1/1 (441/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.828s), StrongSORT:(0.086s)
# video 1/1 (442/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.824s), StrongSORT:(0.104s)
# video 1/1 (443/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.826s), StrongSORT:(0.088s)
# video 1/1 (444/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.860s), StrongSORT:(0.090s)
# video 1/1 (445/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.825s), StrongSORT:(0.172s)
# video 1/1 (446/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.890s), StrongSORT:(0.083s)
# video 1/1 (447/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.830s), StrongSORT:(0.089s)
# video 1/1 (448/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.862s), StrongSORT:(0.077s)
# video 1/1 (449/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.817s), StrongSORT:(0.090s)
# video 1/1 (450/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.877s), StrongSORT:(0.101s)
# video 1/1 (451/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.869s), StrongSORT:(0.090s)
# video 1/1 (452/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.864s), StrongSORT:(0.106s)
# video 1/1 (453/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.869s), StrongSORT:(0.104s)
# video 1/1 (454/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.885s), StrongSORT:(0.103s)
# video 1/1 (455/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.833s), StrongSORT:(0.092s)
# video 1/1 (456/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.840s), StrongSORT:(0.091s)
# video 1/1 (457/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.851s), StrongSORT:(0.105s)
# video 1/1 (458/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.838s), StrongSORT:(0.100s)
# video 1/1 (459/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.832s), StrongSORT:(0.084s)
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# No detections
# video 1/1 (481/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.837s), StrongSORT:(0.087s)
# video 1/1 (482/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.840s), StrongSORT:(0.096s)
# video 1/1 (483/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.869s), StrongSORT:(0.088s)
# video 1/1 (484/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.837s), StrongSORT:(0.144s)
# video 1/1 (485/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.856s), StrongSORT:(0.138s)
# video 1/1 (486/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.845s), StrongSORT:(0.137s)
# video 1/1 (487/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.912s), StrongSORT:(0.146s)
# video 1/1 (488/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.832s), StrongSORT:(0.162s)
# video 1/1 (489/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.837s), StrongSORT:(0.082s)
# video 1/1 (490/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.829s), StrongSORT:(0.150s)
# video 1/1 (491/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.838s), StrongSORT:(0.138s)
# video 1/1 (492/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.819s), StrongSORT:(0.169s)
# video 1/1 (493/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.846s), StrongSORT:(0.148s)
# video 1/1 (494/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.852s), StrongSORT:(0.143s)
# video 1/1 (495/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.798s), StrongSORT:(0.092s)
# video 1/1 (496/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.847s), StrongSORT:(0.165s)
# video 1/1 (497/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.813s), StrongSORT:(0.137s)
# video 1/1 (498/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.853s), StrongSORT:(0.153s)
# video 1/1 (499/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.817s), StrongSORT:(0.140s)
# video 1/1 (500/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 2 oranges, Done. YOLO:(0.830s), StrongSORT:(0.139s)
# video 1/1 (501/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.103s)
# video 1/1 (502/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.814s), StrongSORT:(0.111s)
# video 1/1 (503/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.851s), StrongSORT:(0.096s)
# video 1/1 (504/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.835s), StrongSORT:(0.083s)
# video 1/1 (505/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.900s), StrongSORT:(0.092s)
# video 1/1 (506/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.835s), StrongSORT:(0.098s)
# video 1/1 (507/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.847s), StrongSORT:(0.094s)
# video 1/1 (508/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.841s), StrongSORT:(0.097s)
# video 1/1 (509/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.877s), StrongSORT:(0.099s)
# video 1/1 (510/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.833s), StrongSORT:(0.107s)
# video 1/1 (511/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.843s), StrongSORT:(0.099s)
# video 1/1 (512/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.809s), StrongSORT:(0.107s)
# video 1/1 (513/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.870s), StrongSORT:(0.089s)
# video 1/1 (514/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.857s), StrongSORT:(0.098s)
# video 1/1 (515/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.868s), StrongSORT:(0.104s)
# video 1/1 (516/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.807s), StrongSORT:(0.086s)
# video 1/1 (517/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.099s)
# video 1/1 (518/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.824s), StrongSORT:(0.087s)
# video 1/1 (519/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.862s), StrongSORT:(0.094s)
# video 1/1 (520/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.851s), StrongSORT:(0.114s)
# video 1/1 (521/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.849s), StrongSORT:(0.114s)
# video 1/1 (522/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.872s), StrongSORT:(0.091s)
# video 1/1 (523/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.865s), StrongSORT:(0.103s)
# video 1/1 (524/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.849s), StrongSORT:(0.089s)
# video 1/1 (525/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.816s), StrongSORT:(0.083s)
# video 1/1 (526/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.834s), StrongSORT:(0.093s)
# video 1/1 (527/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.849s), StrongSORT:(0.096s)
# video 1/1 (528/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.902s), StrongSORT:(0.102s)
# video 1/1 (529/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.969s), StrongSORT:(0.098s)
# video 1/1 (530/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.943s), StrongSORT:(0.096s)
# video 1/1 (531/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.872s), StrongSORT:(0.104s)
# video 1/1 (532/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.936s), StrongSORT:(0.106s)
# video 1/1 (533/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.920s), StrongSORT:(0.087s)
# video 1/1 (534/596) D:\code\yolov5\Yolov5_DeepSort_Pytorch\Oranges.mp4: 384x640 1 orange, Done. YOLO:(0.935s), StrongSORT:(0.100s)
